# %% [markdown]
# First, I want to look at a single piece of data and will open up one of the text files. I notice that each text file is an entire book. I also see that the header provides metadata and I assume these text files will have the similar format (Title, Author, Posting Date, Release Date, First Posted, Last Updated, Language, Character set encoding).
#
# In order to answer the questions in part 1, I want to build a dataframe containing the metadata to work with. I also need to separate the actual book text from the metadata.

# %%
import pandas as pd
import re
import os

# %% [markdown]
# Decided to use regular expressions to detect the metadata.
# Defining all the regex here

# %%
#dictionary containing the metadata that I am looking for
metadata_dict = {
    #Using regex to match the pattern, and everything after the pattern up to a '\n'.
    'title': re.compile(r'Title: (?P<title>.*)\n'),
    'author': re.compile(r'Author: (?P<author>.*)\n'),
    'posting_date': re.compile(r'Posting Date: (?P<posting_date>.*)\n'),
    'release_date': re.compile(r'Release Date: (?P<release_date>.*)\n'),
    'first_posted': re.compile(r'First Posted: (?P<first_posted>.*)\n'),
    'last_updated': re.compile(r'Last Updated: (?P<last_updated>.*)\n'),
    'language': re.compile(r'Language: (?P<language>.*)\n'),
    'character_set_encoding': re.compile(r'Character Set Encoding: (?P<character_set_encoding>.*)\n'),
}

# %%
#line parser that checks for regex matches 
def parse_line(line):
    for key, rx in metadata_dict.items():
        match = rx.match(line)
        if match:
            return key, match
    #if metadata is not found
    return None, None

# %%
#empty list that will be appended to after parsing each book
data = []
#looping through files that end with '.txt' within the directory 'gutenberg'
for filename in os.listdir('gutenberg'):
    if filename.endswith('.txt'):
        #creating an empty dict for each book, this will eventually be one element in the 'data' list and one row in the df
        row = {}
        #ignoring encoding/decoding errors
        with open('gutenberg/'+filename, encoding='utf-8', errors='ignore') as f:
            #saving the filename as a data point
            row['Filename'] = filename
            #looping through the first fifty lines
            for i in range(40):
                line = f.readline()
                #calling the line parser to detect metadata
                key, match = parse_line(line)

                if key == 'title':
                    row['Title'] = match.group('title')
                if key == 'author':
                    row['Author'] = match.group('author')
                if key == 'posting_date':
                    row['Posting Date'] = match.group('posting_date')
                if key == 'release_date':
                    row['Release Date'] = match.group('release_date')
                if key == 'first_posted':
                    row['First Posted'] = match.group('first_posted')
                if key == 'last_updated':
                    row['Last Updated'] = match.group('last_updated')
                if key == 'language':
                    row['Language'] = match.group('language')
                if key == 'character_set_encoding':
                    row['Character Set Encoding'] = match.group('character_set_encoding')

        #Parsing the actual book text
            #resetting the read pointer
            f.seek(0)
            raw = f.read()
            #Determining start and stop points of the actual book text
            #Start point can be improved, edge case of *** START ... *** taking more than one line.
            start = re.search(r'\*\*\*.*START.*', raw).end()
            #There is a line before this, usually starting with 'End of the Project' but has variations. The ending point can be improved upon.
            stop = re.search(r'\*\*\*.*END.*', raw).start()
            text = raw[start:stop]
            #replacing non-alphanumerical with space and converting to lower case.
            processed_text = re.sub('[^A-Za-z0-9.]+', ' ', text).lower()
            #Tracking whether the word 'truth' occurs more than twice
            if len(re.findall(r'truth', processed_text)) > 2:
                row['Truth appearing more than twice'] = True
            #Number of times closing quotations appears in the text.
            row['Instances of dialogue'] = len(re.findall(r'\”', text))
            #Number of characters in book
            row['Book Length in Characters'] = len(text)   
            row['Filename'] = filename
            
        data.append(row)

# %% [markdown]
# Now that I have a list of dictionaries, I can convert this directly to a dataframe.

# %%
metadata_df = pd.DataFrame(data)

# %%
metadata_df
# Out:
#                                            Author  Book Length in Characters  \
# 0                                 Dante Alighieri                     561938
# 1             by (AKA B. M. Sinclair) B. M. Bower                     160078
# 2                            Francis Parkman, Jr.                     722277
# 3                                     Oscar Wilde                      82115
# 4                     Mark Twain (Samuel Clemens)                     294746
# 5                             Henry David Thoreau                      67788
# 6       Robert Louis Stevenson and Lloyd Osbourne                     765417
# 7                                George Grossmith                     231288
# 8                                       Zane Grey                     527194
# 9              (AKA Charlotte Bronte) Currer Bell                     501202
# 10                                    Jack London                     287450
# 11                                        Various                     370597
# 12                                    Oscar Wilde                      76841
# 13                                    Henry James                      98973
# 14                                   Henry Lawson                     445432
# 15                                 Walter Raleigh                     146025
# 16                                George Meredith                      81709
# 17                                     Mark Twain                      81628
# 18                           Herbert George Wells                     228608
# 19                           Herbert George Wells                     832358
# 20                                 Henry van Dyke                     297161
# 21                                  Joseph Conrad                     342667
# 22                                    Andrew Lang                     288387
# 23                                  Joseph Conrad                     393622
# 24                                    Oscar Wilde                     235547
# 25                                  Joseph Conrad                     340713
# 26                           Herbert George Wells                     376681
# 27                                    Andrew Lang                      81765
# 28                        Edward Augustus Freeman                     325986
# 29                                     Emile Zola                    1163622
# ..                                            ...                        ...
# 731                               Charles Dickens                     109867
# 732                               Charles Dickens                    1418805
# 733                               Charles Dickens                     103438
# 734                               Charles Dickens                      64790
# 735                               Charles Dickens                      25322
# 736                               Charles Dickens                      39391
# 737                   Mark Twain (Samuel Clemens)                     121203
# 738                                 Samuel Smiles                     824986
# 739  (AKA Kate Douglas Riggs) Kate Douglas Wiggin                     232450
# 740                                   B. M. Bower                     445757
# 741                 Willa Cather and Alfred Noyes                     157445
# 742                         James Fenimore Cooper                     846826
# 743                                  W. H. Hudson                     483142
# 744                  Mr. and Mrs. Haldeman-Julius                     271090
# 745                                  Anthony Hope                          0
# 746                               Charles Dickens                    1880736
# 747                        Alexandre Dumas (Pere)                     411169
# 748                           Thomas Love Peacock                     203739
# 749                               Charles Dickens                    1848519
# 750                               Charles Dickens                    1880392
# 751                                   Anne Bronte                     938337
# 752                                 Joseph Conrad                     521952
# 753                               Rudyard Kipling                     147907
# 754                       Mary E. Wilkins Freeman                      39983
# 755                               Charles Dickens                     757376
# 756                              Booth Tarkington                     469937
# 757                                  Daniel Defoe                     225596
# 758                                   Leo Tolstoy                      96459
# 759                                   Leo Tolstoy                     106114
# 760                    Thomas Wentworth Higginson                     262817
#
#        Filename       First Posted  Instances of dialogue Language  \
# 0    1012-0.txt  September 4, 1997                     52  Italian
# 1    1014-0.txt                NaN                    444  English
# 2    1015-0.txt                NaN                    543  English
# 3    1017-0.txt                NaN                      0  English
# 4     102-0.txt                NaN                      0      NaN
# 5    1022-0.txt                NaN                     38  English
# 6    1024-0.txt                NaN                   2859  English
# 7    1026-0.txt                NaN                    658  English
# 8    1027-0.txt                NaN                   1655  English
# 9    1028-0.txt                NaN                   1218  English
# 10   1029-0.txt                NaN                    893  English
# 11   1030-0.txt                NaN                    232  English
# 12   1031-0.txt                NaN                      0  English
# 13   1032-0.txt                NaN                    337  English
# 14   1036-0.txt                NaN                    208  English
# 15   1038-0.txt                NaN                    149  English
# 16   1042-0.txt                NaN                      0  English
# 17   1044-0.txt                NaN                    292  English
# 18   1046-0.txt                NaN                    159  English
# 19   1047-0.txt                NaN                   1803  English
# 20   1048-0.txt                NaN                    557  English
# 21   1053-0.txt                NaN                    590  English
# 22   1054-0.txt                NaN                    987  English
# 23   1055-0.txt                NaN                   1023  English
# 24   1057-0.txt                NaN                      0  English
# 25   1058-0.txt                NaN                    396  English
# 26   1059-0.txt                NaN                     29  English
# 27   1060-0.txt                NaN                      3  English
# 28   1066-0.txt                NaN                     49  English
# 29   1069-0.txt                NaN                   2657  English
# ..          ...                ...                    ...      ...
# 731   916-0.txt                NaN                      0  English
# 732   917-0.txt                NaN                     58  English
# 733   918-0.txt                NaN                      0  English
# 734   922-0.txt                NaN                      1  English
# 735   924-0.txt                NaN                      1  English
# 736   927-0.txt                NaN                    183  English
# 737    93-0.txt                NaN                    334  English
# 738   935-0.txt                NaN                   1003  English
# 739   936-0.txt                NaN                    457  English
# 740   938-0.txt                NaN                   1722  English
# 741    94-0.txt                NaN                    405  English
# 742   940-0.txt                NaN                   2081  English
# 743   942-0.txt                NaN                    626  English
# 744   945-0.txt                NaN                    623  English
# 745    95-0.txt                NaN                      0  English
# 746   963-0.txt                NaN                     83  English
# 747   965-0.txt                NaN                   1866  English
# 748   966-0.txt                NaN                    807  English
# 749   967-0.txt                NaN                    294  English
# 750   968-0.txt                NaN                    213  English
# 751   969-0.txt                NaN                    192  English
# 752   974-0.txt                NaN                   1313  English
# 753   977-0.txt                NaN                    199  English
# 754   978-0.txt                NaN                    262  English
# 755    98-0.txt                NaN                   2767  English
# 756   980-0.txt                NaN                   3271  English
# 757   983-0.txt                NaN                     34  English
# 758   985-0.txt                NaN                      1  English
# 759   986-0.txt                NaN                      3  English
# 760   993-0.txt                NaN                    830  English
#
#            Last Updated                    Posting Date  \
# 0      December 8, 2014  November 7, 2015 [EBook #1012]
# 1       October 9, 2016     July 27, 2008 [EBook #1014]
# 2     November 18, 2016                             NaN
# 3                   NaN                             NaN
# 4      November 8, 2016                             NaN
# 5         July 22, 2017                             NaN
# 6    September 14, 2016                             NaN
# 7                   NaN                             NaN
# 8      October 14, 2016     July 27, 2008 [EBook #1027]
# 9      November 1, 2016                             NaN
# 10   September 21, 2016    August 2, 2008 [EBook #1029]
# 11                  NaN                             NaN
# 12                  NaN                             NaN
# 13                  NaN                             NaN
# 14      October 9, 2016     July 27, 2008 [EBook #1036]
# 15                  NaN                             NaN
# 16                  NaN                             NaN
# 17                  NaN                             NaN
# 18   September 17, 2016                             NaN
# 19   September 17, 2016    August 2, 2008 [EBook #1047]
# 20      October 9, 2016    August 3, 2008 [EBook #1048]
# 21                  NaN                             NaN
# 22                  NaN                             NaN
# 23                  NaN                             NaN
# 24                  NaN                             NaN
# 25                  NaN                             NaN
# 26   September 17, 2016                             NaN
# 27                  NaN                             NaN
# 28                  NaN                             NaN
# 29    September 5, 2016                             NaN
# ..                  ...                             ...
# 731                 NaN                             NaN
# 732  September 25, 2016                             NaN
# 733                 NaN                             NaN
# 734                 NaN                             NaN
# 735                 NaN                             NaN
# 736                 NaN                             NaN
# 737     August 19, 2016                    May 12, 2009
# 738                 NaN                             NaN
# 739    October 12, 2016     August 7, 2008 [EBook #936]
# 740     October 8, 2016      July 26, 2008 [EBook #938]
# 741     October 6, 2016                             NaN
# 742    October 21, 2016                             NaN
# 743    October 22, 2016      July 26, 2008 [EBook #942]
# 744    November 7, 2016      July 26, 2008 [EBook #945]
# 745    October 22, 2016                             NaN
# 746  September 25, 2016      July 26, 2008 [EBook #963]
# 747   November 21, 2016     August 5, 2008 [EBook #965]
# 748   November 18, 2016      July 27, 2008 [EBook #966]
# 749  September 25, 2016                             NaN
# 750  September 25, 2016                             NaN
# 751                 NaN                             NaN
# 752                 NaN                             NaN
# 753     October 7, 2016      July 21, 2008 [EBook #977]
# 754    November 6, 2016    August 10, 2008 [EBook #978]
# 755  September 25, 2016               November 28, 2009
# 756  September 16, 2016      July 21, 2008 [EBook #980]
# 757                 NaN                             NaN
# 758  September 10, 2016                    July 9, 2009
# 759  September 10, 2016                    July 9, 2009
# 760    November 8, 2016      July 27, 2008 [EBook #993]
#
#                           Release Date  \
# 0                         August, 1997
# 1                         August, 1997
# 2         April 27, 2006 [EBook #1015]
# 3    September 26, 2014  [eBook #1017]
# 4         August 20, 2006 [EBook #102]
# 5         August 7, 2008 [EBook #1022]
# 6      February 11, 2006 [EBook #1024]
# 7       August 14, 2011  [eBook #1026]
# 8                          August 1997
# 9         August 6, 2008 [EBook #1028]
# 10                                 NaN
# 11    February 22, 2015  [eBook #1030]
# 12   September 19, 2014  [eBook #1031]
# 13    December 24, 2010  [eBook #1032]
# 14                     September, 1997
# 15       April 14, 2013  [eBook #1038]
# 16       April 18, 2013  [eBook #1042]
# 17    February 14, 2013  [eBook #1044]
# 18           May 3, 2006 [EBook #1046]
# 19                     September, 1997
# 20                     September, 1997
# 21      January 5, 2011  [eBook #1053]
# 22     February 6, 2015  [eBook #1054]
# 23        April 9, 2013  [eBook #1055]
# 24       March 31, 2013  [eBook #1057]
# 25        April 7, 2013  [eBook #1058]
# 26     February 11, 2006 [EBook #1059]
# 27   September 16, 2014  [eBook #1060]
# 28       March 20, 2013  [eBook #1066]
# 29           May 3, 2006 [EBook #1069]
# ..                                 ...
# 731       April 11, 2015  [eBook #916]
# 732        April 27, 2006 [EBook #917]
# 733       April 14, 2015  [eBook #918]
# 734      January 4, 2015  [eBook #922]
# 735     January 11, 2015  [eBook #924]
# 736     January 11, 2015  [eBook #927]
# 737        December, 1993  [Etext #93]
# 738    December 28, 2014  [eBook #935]
# 739                         June, 1997
# 740                         June, 1997
# 741          March 7, 2006 [EBook #94]
# 742      February 5, 2006 [EBook #940]
# 743                         June, 1997
# 744                         June, 1997
# 745       January 10, 2006 [EBook #95]
# 746                         July, 1997
# 747                         June, 1997
# 748                          June 1997
# 749        April 27, 2006 [EBook #967]
# 750        April 27, 2006 [EBook #968]
# 751     February 2, 2010  [eBook #969]
# 752    December 24, 2010  [eBook #974]
# 753                         July, 1997
# 754                         July, 1997
# 755          January, 1994 [EBook #98]
# 756                         July, 1997
# 757     February 8, 2015  [eBook #983]
# 758           July, 1997  [Etext #985]
# 759           July, 1997  [Etext #986]
# 760                          July 1997
#
#                                                  Title  \
# 0                          La Divina Commedia di Dante
# 1                           The Lure of the Dim Trails
# 2                                     The Oregon Trail
# 3                                      The Soul of Man
# 4                     The Tragedy of Pudd'nhead Wilson
# 5                                              Walking
# 6                                          The Wrecker
# 7                                The Diary of a Nobody
# 8                                 The Lone Star Ranger
# 9                                        The Professor
# 10                                      The Night-Born
# 11           The Cavalier Songs and Ballads of England
# 12                           Charmides and Other Poems
# 13                                           The Pupil
# 14                            Joe Wilson and His Mates
# 15                                               Style
# 16                                   A Reading of Life
# 17   Extract from Captain Stormfield's Visit to Heaven
# 18                              God The Invisible King
# 19                                 The New Machiavelli
# 20                                  The Ruling Passion
# 21                                    Within the Tides
# 22                             A Collection of Ballads
# 23                                   'Twixt Land & Sea
# 24                                               Poems
# 25                               The Mirror of the Sea
# 26                                  The World Set Free
# 27                                  Grass of Parnassus
# 28                               William the Conqueror
# 29   Nana, The Miller’s Daughter, Captain Burle, De...
# ..                                                 ...
# 731                          Sketches of Young Couples
# 732                                      Barnaby Rudge
# 733                        Sketches of Young Gentlemen
# 734                           Sunday under Three Heads
# 735                                 To be Read at Dusk
# 736                                    The Lamplighter
# 737                              Tom Sawyer, Detective
# 738                                          Self-Help
# 739                            The Village Watch-Tower
# 740                                        Good Indian
# 741            Alexander’s Bridge and The Barrel Organ
# 742                           The Last of the Mohicans
# 743                                     Green Mansions
# 744                                               Dust
# 745                              The Prisoner of Zenda
# 746                                      Little Dorrit
# 747                                    The Black Tulip
# 748                                        Maid Marian
# 749       The Life And Adventures Of Nicholas Nickleby
# 750           Life And Adventures Of Martin Chuzzlewit
# 751                        The Tenant of Wildfell Hall
# 752                                   The Secret Agent
# 753                                     American Notes
# 754                                    The Yates Pride
# 755                               A Tale of Two Cities
# 756                                        Alice Adams
# 757  Tour through the Eastern Counties of England, ...
# 758                                     Father Sergius
# 759                                     Master and Man
# 760                                            Malbone
#
#     Truth appearing more than twice
# 0                               NaN
# 1                              True
# 2                              True
# 3                               NaN
# 4                              True
# 5                              True
# 6                              True
# 7                              True
# 8                              True
# 9                              True
# 10                             True
# 11                             True
# 12                              NaN
# 13                             True
# 14                             True
# 15                             True
# 16                             True
# 17                              NaN
# 18                             True
# 19                             True
# 20                             True
# 21                             True
# 22                             True
# 23                             True
# 24                             True
# 25                             True
# 26                             True
# 27                              NaN
# 28                             True
# 29                             True
# ..                              ...
# 731                            True
# 732                            True
# 733                            True
# 734                             NaN
# 735                             NaN
# 736                             NaN
# 737                             NaN
# 738                            True
# 739                            True
# 740                            True
# 741                             NaN
# 742                            True
# 743                            True
# 744                            True
# 745                             NaN
# 746                            True
# 747                            True
# 748                            True
# 749                            True
# 750                            True
# 751                            True
# 752                            True
# 753                            True
# 754                             NaN
# 755                            True
# 756                            True
# 757                             NaN
# 758                            True
# 759                             NaN
# 760                            True
#
# [761 rows x 11 columns]

# %% [markdown]
# I want to see if there are any missing values for each of the columns to decide which columns to use when answering questions. Will also do some general statistics.
# I also notice from a quick glance, that the date columns need cleaning as well. Some contain extra words (i.e. August 20, 2006 [EBook #102]) or different formats of date (i.e. August 1997).

# %%
percent_missing = metadata_df.isnull().sum() * 100 / len(metadata_df)
percent_missing.sort_values()
# Out:
# Book Length in Characters           0.000000
# Filename                            0.000000
# Instances of dialogue               0.000000
# Title                               0.000000
# Author                              0.131406
# Language                            0.131406
# Release Date                        2.759527
# Truth appearing more than twice    18.134034
# Last Updated                       24.572930
# Posting Date                       52.036794
# First Posted                       98.685940
# dtype: float64

# %%
metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 11 columns):
# Author                             760 non-null object
# Book Length in Characters          761 non-null int64
# Filename                           761 non-null object
# First Posted                       10 non-null object
# Instances of dialogue              761 non-null int64
# Language                           760 non-null object
# Last Updated                       574 non-null object
# Posting Date                       365 non-null object
# Release Date                       740 non-null object
# Title                              761 non-null object
# Truth appearing more than twice    623 non-null object
# dtypes: int64(2), object(9)
# memory usage: 65.5+ KB

# %% [markdown]
# There are a total of 761 rows, which when compared to the number of files in the folder ending in .txt, is a match.

# %% [markdown]
# In which books does the word "truth" appear more than twice?

# %%
#Selecting book titles that have a value of True in the column 'Truth appearing more than twice'
metadata_df['Title'].loc[metadata_df['Truth appearing more than twice'] == True]
# Out:
# 1                             The Lure of the Dim Trails
# 2                                       The Oregon Trail
# 4                       The Tragedy of Pudd'nhead Wilson
# 5                                                Walking
# 6                                            The Wrecker
# 7                                  The Diary of a Nobody
# 8                                   The Lone Star Ranger
# 9                                          The Professor
# 10                                        The Night-Born
# 11             The Cavalier Songs and Ballads of England
# 13                                             The Pupil
# 14                              Joe Wilson and His Mates
# 15                                                 Style
# 16                                     A Reading of Life
# 18                                God The Invisible King
# 19                                   The New Machiavelli
# 20                                    The Ruling Passion
# 21                                      Within the Tides
# 22                               A Collection of Ballads
# 23                                     'Twixt Land & Sea
# 24                                                 Poems
# 25                                 The Mirror of the Sea
# 26                                    The World Set Free
# 28                                 William the Conqueror
# 29     Nana, The Miller’s Daughter, Captain Burle, De...
# 30                                          The Sea-Wolf
# 31                            The Strength of the Strong
# 32                                The Wallet of Kai Lung
# 33                                 The Mirror of Kong Ho
# 34                              The Scouts of the Valley
#                              ...
# 717                                           Intentions
# 719                                The Rose and the Ring
# 721                            Wonderful Balloon Ascents
# 723                                    The White Company
# 724                                Her Father’s Daughter
# 725                                       Within the Law
# 728                        The Mudfog and Other Sketches
# 729                                   A Hero of Our Time
# 730                           The Uncommercial Traveller
# 731                            Sketches of Young Couples
# 732                                        Barnaby Rudge
# 733                          Sketches of Young Gentlemen
# 738                                            Self-Help
# 739                              The Village Watch-Tower
# 740                                          Good Indian
# 742                             The Last of the Mohicans
# 743                                       Green Mansions
# 744                                                 Dust
# 746                                        Little Dorrit
# 747                                      The Black Tulip
# 748                                          Maid Marian
# 749         The Life And Adventures Of Nicholas Nickleby
# 750             Life And Adventures Of Martin Chuzzlewit
# 751                          The Tenant of Wildfell Hall
# 752                                     The Secret Agent
# 753                                       American Notes
# 755                                 A Tale of Two Cities
# 756                                          Alice Adams
# 758                                       Father Sergius
# 760                                              Malbone
# Name: Title, Length: 623, dtype: object

# %% [markdown]
# Which book has the most dialogue between characters?

# %%
#Querying the row with the max value in column 'Instances of dialogue'
metadata_df.loc[metadata_df['Instances of dialogue'].idxmax()]
# Out:
# Author                                      Alexandre Dumas, père
# Book Length in Characters                                 2624640
# Filename                                               1184-0.txt
# First Posted                                                  NaN
# Instances of dialogue                                       15194
# Language                                                  English
# Last Updated                                    February 24, 2017
# Posting Date                                                  NaN
# Release Date                       November 8, 2008 [EBook #1184]
# Title                                   The Count of Monte Cristo
# Truth appearing more than twice                              True
# Name: 64, dtype: object

# %%
metadata_df.loc[metadata_df['Book Length in Characters'].idxmax()]
# Out:
# Author                                            Victor Hugo
# Book Length in Characters                             3235163
# Filename                                            135-0.txt
# First Posted                                              NaN
# Instances of dialogue                                       0
# Language                                              English
# Last Updated                                 January 18, 2016
# Posting Date                                              NaN
# Release Date                       June 22, 2008 [EBook #135]
# Title                                          Les Misérables
# Truth appearing more than twice                          True
# Name: 148, dtype: object

# %% [markdown]
# English to non-English

# %%
#dropping rows with null values in the Language column
language_df = metadata_df.dropna(subset=['Language'])
language_df['Language'].value_counts(normalize=True)*100
# Out:
# English     99.210526
# French       0.526316
# Japanese     0.131579
# Italian      0.131579
# Name: Language, dtype: float64

# %% [markdown]
# Most common release date

# %%
#Without cleansing
metadata_df['Release Date'].mode()
# Out:
# 0    May, 1999
# dtype: object

# %%
mode_df = metadata_df
#removing [Ebook #]
mode_df['Release Date'] = mode_df['Release Date'].str.replace(r'\[.*\].*','')
#removing whitespace
mode_df['Release Date'] = mode_df['Release Date'].str.strip()
#regex looking for a word character, followed by a space, followed by four digits. Adding the comma if found (i.e. August 1997 to August, 1997)
mode_df['Release Date'] = mode_df['Release Date'].str.replace(r'(\w)( \d{4})', r'\1,\2')

# %%
mode_df['Release Date'].mode()
# Out:
# 0    August, 1999
# dtype: object

# %% [markdown]
# Average Release Date (year only)

# %%
#initializing df under a different name, dedicated for this problem
average_df = pd.DataFrame(data)
#found outlier with text after the [EBook #], removing everything after [] including []
average_df['Release Date'] = average_df['Release Date'].str.replace(r'\[.*\].*','')
#stripping any white spaces
average_df['Release Date'] = average_df['Release Date'].str.strip()
#Creating new column 'Release Year' by taking last four chars of 'Release Date'
average_df['Release Year'] = average_df['Release Date'].str[-4:]
#removing rows with null values in the column 'Release Year'
average_df = average_df.dropna(subset=['Release Year'])
#converting to int
average_df['Release Year'] = average_df['Release Year'].astype(int)

# %%
avg_year = average_df['Release Year'].mean()
print(avg_year)
print(round(avg_year))
# Out:
# 2003.495945945946
# 2003
